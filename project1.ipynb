# %%
import pyautogui
import pyperclip
import time

pyautogui.PAUSE = 1
# abrir a nova aba
pyautogui.hotkey('ctrl', 't')
# digitar a url
pyperclip.copy('https://drive.google.com/drive/folders/149xknr9JvrlEnhNWO49zPcw0PW5icxga')
pyautogui.hotkey('ctrl' , 'v')
# entrar no site digitado
pyautogui.press('enter')
time.sleep(5)
# clicar na base de dados 2 vezes
pyautogui.click(x=-880, y=268 , clicks=2)
time.sleep(2)
# clicar no arquivo
pyautogui.click(x=-846, y=335)
time.sleep(2)
# clicar nos 3 pontinhos
pyautogui.click(x=-204, y=161)
# clicar em download
pyautogui.click(x=-451, y=561)
time.sleep(4)

# %%
import pandas as pd

biblioteca = pd.read_excel(r'C:\Users\Usuario\Downloads\Vendas - Dez.xlsx')
display(biblioteca)
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 0            65014 2019-12-01            Shopping Morumbi    Sunga Listrado
# 1            65014 2019-12-01            Shopping Morumbi   Casaco Listrado
# 2            65016 2019-12-01           Iguatemi Campinas   Sapato Listrado
# 3            65016 2019-12-01           Iguatemi Campinas            Casaco
# 4            65017 2019-12-01          Shopping SP Market        Gorro Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final
# ...

# %%
# Soma dos elementos para passar pro email
faturamento = biblioteca['Valor Final'].sum()
quantidade = biblioteca['Quantidade'].sum()
# Out:
# 2917311

# %%
# enviando o email
pyautogui.hotkey('ctrl' , 't')
pyperclip.copy('https://outlook.live.com/mail/0/')
pyautogui.hotkey('ctrl' , 'v')
pyautogui.press('enter')
time.sleep(6)
pyautogui.click(x=-1032, y=138)
pyautogui.click(x=-881, y=198)
pyperclip.copy('renanvraau@gmail.com')
pyautogui.hotkey('ctrl' , 'v')
pyautogui.press('tab')
time.sleep(2)
pyperclip.copy('Faturamento de dezembro')
pyautogui.hotkey('ctrl' , 'v')
pyautogui.press('tab')
time.sleep(2)
texto = f"""Ola, 
venho trazer os resultados do mês de dezembro

tivemos o faturamento sendo {faturamento:,.2f}
e a quantidade de vendas sendo {quantidade:,}

abs 
Renan do Python"""
pyperclip.copy(texto)
pyautogui.hotkey('ctrl' , 'v')
time.sleep(2)
pyautogui.hotkey('ctrl' , 'enter')

# %%
time.sleep(5)
pyautogui.position()
# Out:
# Point(x=-881, y=198)
